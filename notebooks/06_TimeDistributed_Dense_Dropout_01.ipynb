# %% [markdown]
# # VI. TimeDistributed Dense Output with Dropout (0.1)
# Lower dropout rate for minimal regularization comparison.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
import warnings; warnings.filterwarnings('ignore')

df = pd.read_csv('../dl_service/data/cattle_training_data.csv', parse_dates=['timestamp'])
FEATURES = ['temperature', 'humidity', 'heartRate', 'distance', 'hour', 'day_of_week']
SEQUENCE_LENGTH = 30
N_FEATURES = len(FEATURES)

df_normal = df[df['is_anomaly']==0].dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(df_normal[FEATURES].values)

def create_sequences(data, sl):
    return np.array([data[i:i+sl] for i in range(len(data)-sl+1)], dtype=np.float32)

all_seq = create_sequences(scaled, SEQUENCE_LENGTH)
print(f"Sequences: {all_seq.shape}")
# Out:
# Sequences: (20926, 30, 6)

# %%
MODEL_NAME = 'LSTM Autoencoder (Dropout 0.1)'
model = models.Sequential([
    layers.Input(shape=(SEQUENCE_LENGTH, N_FEATURES)),
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.Dropout(0.1),
    layers.LSTM(64, activation='tanh', return_sequences=False),
    layers.Dropout(0.1),
    layers.RepeatVector(SEQUENCE_LENGTH),
    layers.LSTM(64, activation='tanh', return_sequences=True),
    layers.Dropout(0.1),
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.TimeDistributed(layers.Dense(N_FEATURES)),
])
model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 30, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 30, 6)          │           774 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,142 (981.02 KB)
#  Trainable params: 251,142 (981.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(all_seq, all_seq, epochs=100, batch_size=64, validation_split=0.15,
    callbacks=[callbacks.EarlyStopping(monitor='val_loss',patience=12,restore_best_weights=True),
               callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=6,min_lr=1e-6)], verbose=1)
train_recon = model.predict(all_seq, verbose=0)
train_errors = np.mean(np.square(all_seq - train_recon), axis=(1,2))
print(f"Mean Error: {np.mean(train_errors):.6f}")
# Out:
# Epoch 1/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 53s 173ms/step - loss: 0.0276 - val_loss: 0.0146 - learning_rate: 0.0010
# Epoch 2/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 48s 174ms/step - loss: 0.0149 - val_loss: 0.0134 - learning_rate: 0.0010
# Epoch 3/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 50s 181ms/step - loss: 0.0141 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 4/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 55s 199ms/step - loss: 0.0134 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 5/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 54s 193ms/step - loss: 0.0129 - val_loss: 0.0122 - learning_rate: 0.0010
# Epoch 6/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 56s 201ms/step - loss: 0.0126 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 7/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 54s 194ms/step - loss: 0.0125 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 8/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 52s 185ms/step - loss: 0.0123 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 9/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 53s 191ms/step - loss: 0.0122 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 10/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 54s 194ms/step - loss: 0.0121 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 11/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 64s 230ms/step - loss: 0.0121 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 12/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 305ms/step - loss: 0.0120 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 13/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 62s 224ms/step - loss: 0.0119 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 14/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 62s 223ms/step - loss: 0.0118 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 15/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 65s 232ms/step - loss: 0.0118 - val_loss: 0.0112 - learning_rate: 0.0010
# Epoch 16/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 63s 228ms/step - loss: 0.0116 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 17/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 254ms/step - loss: 0.0116 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 18/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 65s 235ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 19/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 61s 221ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 20/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 322ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 21/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 87s 313ms/step - loss: 0.0113 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 22/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 294ms/step - loss: 0.0112 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 23/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 306ms/step - loss: 0.0111 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 24/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 87s 314ms/step - loss: 0.0110 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 25/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 307ms/step - loss: 0.0109 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 26/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 296ms/step - loss: 0.0109 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 27/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 301ms/step - loss: 0.0111 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 28/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 303ms/step - loss: 0.0107 - val_loss: 0.0104 - learning_rate: 5.0000e-04
# Epoch 29/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 76s 273ms/step - loss: 0.0106 - val_loss: 0.0103 - learning_rate: 5.0000e-04
# Epoch 30/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 271ms/step - loss: 0.0106 - val_loss: 0.0103 - learning_rate: 5.0000e-04
# Epoch 31/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 77s 277ms/step - loss: 0.0105 - val_loss: 0.0102 - learning_rate: 5.0000e-04
# Epoch 32/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 269ms/step - loss: 0.0105 - val_loss: 0.0104 - learning_rate: 5.0000e-04
# Epoch 33/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 66s 236ms/step - loss: 0.0105 - val_loss: 0.0101 - learning_rate: 5.0000e-04
# Epoch 34/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 65s 234ms/step - loss: 0.0104 - val_loss: 0.0101 - learning_rate: 5.0000e-04
# Epoch 35/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 63s 226ms/step - loss: 0.0104 - val_loss: 0.0100 - learning_rate: 5.0000e-04
# Epoch 36/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 69s 248ms/step - loss: 0.0103 - val_loss: 0.0100 - learning_rate: 5.0000e-04
# Epoch 37/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 73s 263ms/step - loss: 0.0103 - val_loss: 0.0099 - learning_rate: 5.0000e-04
# Epoch 38/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 73s 264ms/step - loss: 0.0102 - val_loss: 0.0099 - learning_rate: 5.0000e-04
# Epoch 39/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 63s 227ms/step - loss: 0.0102 - val_loss: 0.0098 - learning_rate: 5.0000e-04
# Epoch 40/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 61s 219ms/step - loss: 0.0101 - val_loss: 0.0098 - learning_rate: 5.0000e-04
# Epoch 41/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 61s 220ms/step - loss: 0.0100 - val_loss: 0.0099 - learning_rate: 5.0000e-04
# Epoch 42/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 66s 237ms/step - loss: 0.0100 - val_loss: 0.0097 - learning_rate: 5.0000e-04
# Epoch 43/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 260ms/step - loss: 0.0099 - val_loss: 0.0096 - learning_rate: 5.0000e-04
# Epoch 44/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 78s 281ms/step - loss: 0.0099 - val_loss: 0.0095 - learning_rate: 5.0000e-04
# Epoch 45/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 269ms/step - loss: 0.0098 - val_loss: 0.0096 - learning_rate: 5.0000e-04
# Epoch 46/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 70s 253ms/step - loss: 0.0098 - val_loss: 0.0095 - learning_rate: 5.0000e-04
# Epoch 47/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 259ms/step - loss: 0.0097 - val_loss: 0.0093 - learning_rate: 5.0000e-04
# Epoch 48/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 269ms/step - loss: 0.0097 - val_loss: 0.0093 - learning_rate: 5.0000e-04
# Epoch 49/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 269ms/step - loss: 0.0096 - val_loss: 0.0092 - learning_rate: 5.0000e-04
# Epoch 50/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 73s 262ms/step - loss: 0.0096 - val_loss: 0.0092 - learning_rate: 5.0000e-04
# Epoch 51/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 65s 235ms/step - loss: 0.0095 - val_loss: 0.0092 - learning_rate: 5.0000e-04
# Epoch 52/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 65s 234ms/step - loss: 0.0095 - val_loss: 0.0091 - learning_rate: 5.0000e-04
# Epoch 53/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 69s 247ms/step - loss: 0.0094 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 54/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 254ms/step - loss: 0.0093 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 55/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 70s 253ms/step - loss: 0.0093 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 56/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 66s 236ms/step - loss: 0.0093 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 57/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 68s 243ms/step - loss: 0.0092 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 58/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 68s 245ms/step - loss: 0.0092 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 59/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 69s 248ms/step - loss: 0.0092 - val_loss: 0.0086 - learning_rate: 5.0000e-04
# Epoch 60/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 66s 237ms/step - loss: 0.0091 - val_loss: 0.0086 - learning_rate: 5.0000e-04
# Epoch 61/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 73s 262ms/step - loss: 0.0091 - val_loss: 0.0087 - learning_rate: 5.0000e-04
# Epoch 62/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 70s 253ms/step - loss: 0.0090 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 63/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 70s 251ms/step - loss: 0.0090 - val_loss: 0.0084 - learning_rate: 5.0000e-04
# Epoch 64/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 74s 265ms/step - loss: 0.0089 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 65/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 75s 269ms/step - loss: 0.0089 - val_loss: 0.0083 - learning_rate: 5.0000e-04
# Epoch 66/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 76s 274ms/step - loss: 0.0088 - val_loss: 0.0083 - learning_rate: 5.0000e-04
# Epoch 67/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 78s 280ms/step - loss: 0.0088 - val_loss: 0.0083 - learning_rate: 5.0000e-04
# Epoch 68/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 292ms/step - loss: 0.0088 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 69/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 79s 285ms/step - loss: 0.0087 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 70/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 80s 286ms/step - loss: 0.0087 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 71/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 78s 281ms/step - loss: 0.0086 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 72/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 78s 280ms/step - loss: 0.0086 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 73/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 293ms/step - loss: 0.0086 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 74/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 293ms/step - loss: 0.0085 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 75/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 306ms/step - loss: 0.0086 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 76/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 83s 300ms/step - loss: 0.0084 - val_loss: 0.0079 - learning_rate: 5.0000e-04
# Epoch 77/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 339ms/step - loss: 0.0084 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 78/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 98s 354ms/step - loss: 0.0083 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 79/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 380ms/step - loss: 0.0083 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 80/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 97s 349ms/step - loss: 0.0083 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 81/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 97s 350ms/step - loss: 0.0082 - val_loss: 0.0077 - learning_rate: 5.0000e-04
# Epoch 82/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 102s 366ms/step - loss: 0.0083 - val_loss: 0.0079 - learning_rate: 5.0000e-04
# Epoch 83/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 103s 369ms/step - loss: 0.0082 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 84/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 104s 375ms/step - loss: 0.0082 - val_loss: 0.0077 - learning_rate: 5.0000e-04
# Epoch 85/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 102s 366ms/step - loss: 0.0081 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 86/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 109s 393ms/step - loss: 0.0081 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 87/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 105s 377ms/step - loss: 0.0080 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 88/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 115s 414ms/step - loss: 0.0081 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 89/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 110s 396ms/step - loss: 0.0080 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 90/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 111s 400ms/step - loss: 0.0081 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 91/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 113s 406ms/step - loss: 0.0080 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 92/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 113s 407ms/step - loss: 0.0079 - val_loss: 0.0074 - learning_rate: 5.0000e-04
# Epoch 93/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 111s 398ms/step - loss: 0.0079 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 94/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 114s 409ms/step - loss: 0.0079 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 95/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 112s 402ms/step - loss: 0.0079 - val_loss: 0.0074 - learning_rate: 5.0000e-04
# Epoch 96/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 107s 384ms/step - loss: 0.0078 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 97/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 111s 401ms/step - loss: 0.0078 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 98/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 108s 389ms/step - loss: 0.0078 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 99/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 120s 432ms/step - loss: 0.0077 - val_loss: 0.0073 - learning_rate: 2.5000e-04
# Epoch 100/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 113s 407ms/step - loss: 0.0076 - val_loss: 0.0073 - learning_rate: 2.5000e-04
# Mean Error: 0.007037

# %%
# Evaluate on full dataset
df_all = df.dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
test_scaled = scaler.transform(df_all[FEATURES].values)
test_seq = create_sequences(test_scaled, SEQUENCE_LENGTH)
test_recon = model.predict(test_seq, verbose=0)
test_errors = np.mean(np.square(test_seq - test_recon), axis=(1,2))
threshold = float(np.percentile(train_errors, 98))
preds = (test_errors > threshold).astype(int)
actuals = df_all['is_anomaly'].values[SEQUENCE_LENGTH-1:][:len(preds)]
print(classification_report(actuals, preds, target_names=['Normal','Anomaly']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.49      0.66     20926
#      Anomaly       0.05      0.91      0.10       645
#
#     accuracy                           0.50     21571
#    macro avg       0.52      0.70      0.38     21571
# weighted avg       0.97      0.50      0.64     21571

# %%
# Training Loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss', color='#2196F3', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', color='#FF5722', linewidth=2)
plt.title(MODEL_NAME+' - Training vs Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch'); plt.ylabel('MSE'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Reconstruction Error
plt.figure(figsize=(10,5))
plt.hist(train_errors, bins=80, color='#2196F3', alpha=0.7, edgecolor='black')
plt.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.title(MODEL_NAME+' - Reconstruction Error Distribution', fontsize=14, fontweight='bold')
plt.xlabel('MSE'); plt.ylabel('Frequency'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Confusion Matrix
cm = confusion_matrix(actuals, preds)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal','Anomaly'], yticklabels=['Normal','Anomaly'])
plt.title(MODEL_NAME+' - Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.tight_layout(); plt.show()

# ROC Curve
fpr,tpr,_ = roc_curve(actuals, test_errors[:len(actuals)])
roc_auc = auc(fpr,tpr)
plt.figure(figsize=(7,5))
plt.plot(fpr,tpr, color='#2196F3', linewidth=2, label=f'AUC = {roc_auc:.4f}')
plt.plot([0,1],[0,1], color='gray', linestyle='--')
plt.title(MODEL_NAME+' - ROC Curve', fontsize=14, fontweight='bold')
plt.xlabel('FPR'); plt.ylabel('TPR'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()
print(f"AUC Score: {roc_auc:.4f}")

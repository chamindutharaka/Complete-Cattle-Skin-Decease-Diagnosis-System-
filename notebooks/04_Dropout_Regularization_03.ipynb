# %% [markdown]
# # IV. Dropout Regularization Layer (rate: 0.3)
# Higher dropout rate for stronger regularization comparison.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
import warnings; warnings.filterwarnings('ignore')

df = pd.read_csv('../dl_service/data/cattle_training_data.csv', parse_dates=['timestamp'])
FEATURES = ['temperature', 'humidity', 'heartRate', 'distance', 'hour', 'day_of_week']
SEQUENCE_LENGTH = 30
N_FEATURES = len(FEATURES)

df_normal = df[df['is_anomaly']==0].dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(df_normal[FEATURES].values)

def create_sequences(data, sl):
    return np.array([data[i:i+sl] for i in range(len(data)-sl+1)], dtype=np.float32)

all_seq = create_sequences(scaled, SEQUENCE_LENGTH)
print(f"Sequences: {all_seq.shape}")
# Out:
# Sequences: (20926, 30, 6)

# %%
MODEL_NAME = 'LSTM Autoencoder (Dropout 0.3)'
model = models.Sequential([
    layers.Input(shape=(SEQUENCE_LENGTH, N_FEATURES)),
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.Dropout(0.3),
    layers.LSTM(64, activation='tanh', return_sequences=False),
    layers.Dropout(0.3),
    layers.RepeatVector(SEQUENCE_LENGTH),
    layers.LSTM(64, activation='tanh', return_sequences=True),
    layers.Dropout(0.3),
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.TimeDistributed(layers.Dense(N_FEATURES)),
])
model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 30, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 30, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 6)          │           774 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,142 (981.02 KB)
#  Trainable params: 251,142 (981.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(all_seq, all_seq, epochs=100, batch_size=64, validation_split=0.15,
    callbacks=[callbacks.EarlyStopping(monitor='val_loss',patience=12,restore_best_weights=True),
               callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=6,min_lr=1e-6)], verbose=1)
train_recon = model.predict(all_seq, verbose=0)
train_errors = np.mean(np.square(all_seq - train_recon), axis=(1,2))
print(f"Mean Error: {np.mean(train_errors):.6f}")
# Out:
# Epoch 1/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - loss: 0.0295 - val_loss: 0.0153 - learning_rate: 0.0010
# Epoch 2/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.0163 - val_loss: 0.0141 - learning_rate: 0.0010
# Epoch 3/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 0.0150 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 4/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0143 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 5/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 79ms/step - loss: 0.0138 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 6/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 85ms/step - loss: 0.0135 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 7/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 79ms/step - loss: 0.0133 - val_loss: 0.0124 - learning_rate: 0.0010
# Epoch 8/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - loss: 0.0131 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 9/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 79ms/step - loss: 0.0129 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 10/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 78ms/step - loss: 0.0129 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 11/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 78ms/step - loss: 0.0127 - val_loss: 0.0122 - learning_rate: 0.0010
# Epoch 12/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 83ms/step - loss: 0.0126 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 13/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0126 - val_loss: 0.0119 - learning_rate: 0.0010
# Epoch 14/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 85ms/step - loss: 0.0125 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 15/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 79ms/step - loss: 0.0124 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 16/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0125 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 17/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0126 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 18/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - loss: 0.0124 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 19/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - loss: 0.0123 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 20/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 83ms/step - loss: 0.0122 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 21/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0122 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 22/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0120 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 23/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 87ms/step - loss: 0.0120 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 24/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0120 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 25/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0119 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 26/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 83ms/step - loss: 0.0119 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 27/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0117 - val_loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 28/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0117 - val_loss: 0.0113 - learning_rate: 5.0000e-04
# Epoch 29/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0117 - val_loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 30/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 85ms/step - loss: 0.0117 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 31/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0117 - val_loss: 0.0113 - learning_rate: 5.0000e-04
# Epoch 32/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0117 - val_loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 33/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0116 - val_loss: 0.0113 - learning_rate: 5.0000e-04
# Epoch 34/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0115 - val_loss: 0.0112 - learning_rate: 2.5000e-04
# Epoch 35/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0116 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 36/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0116 - val_loss: 0.0112 - learning_rate: 2.5000e-04
# Epoch 37/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 38/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 83ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 39/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 40/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 85ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 41/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0115 - val_loss: 0.0112 - learning_rate: 2.5000e-04
# Epoch 42/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 43/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 2.5000e-04
# Epoch 44/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 1.2500e-04
# Epoch 45/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 1.2500e-04
# Epoch 46/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 1.2500e-04
# Epoch 47/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 85ms/step - loss: 0.0114 - val_loss: 0.0112 - learning_rate: 1.2500e-04
# Epoch 48/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 22s 80ms/step - loss: 0.0114 - val_loss: 0.0110 - learning_rate: 1.2500e-04
# Epoch 49/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 1.2500e-04
# Epoch 50/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 379s 1s/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 6.2500e-05
# Epoch 51/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0114 - val_loss: 0.0110 - learning_rate: 6.2500e-05
# Epoch 52/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 6.2500e-05
# Epoch 53/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 6.2500e-05
# Epoch 54/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 88ms/step - loss: 0.0114 - val_loss: 0.0111 - learning_rate: 6.2500e-05
# Epoch 55/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 86ms/step - loss: 0.0114 - val_loss: 0.0110 - learning_rate: 6.2500e-05
# Epoch 56/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0114 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 57/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 58/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 3.1250e-05
# Epoch 59/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 60/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 61/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 3.1250e-05
# Epoch 62/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 92ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 63/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 27s 97ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 1.5625e-05
# Epoch 64/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 1.5625e-05
# Epoch 65/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 83ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 1.5625e-05
# Epoch 66/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 1.5625e-05
# Epoch 67/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 82ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 1.5625e-05
# Epoch 68/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 1.5625e-05
# Epoch 69/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 23s 84ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 7.8125e-06
# Epoch 70/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 7.8125e-06
# Epoch 71/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 7.8125e-06
# Epoch 72/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 7.8125e-06
# Epoch 73/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 7.8125e-06
# Epoch 74/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 87ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 7.8125e-06
# Epoch 75/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 24s 88ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.9063e-06
# Epoch 76/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.9063e-06
# Epoch 77/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.9063e-06
# Epoch 78/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 25s 92ms/step - loss: 0.0113 - val_loss: 0.0110 - learning_rate: 3.9063e-06
# Mean Error: 0.010995

# %%
# Evaluate on full dataset
df_all = df.dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
test_scaled = scaler.transform(df_all[FEATURES].values)
test_seq = create_sequences(test_scaled, SEQUENCE_LENGTH)
test_recon = model.predict(test_seq, verbose=0)
test_errors = np.mean(np.square(test_seq - test_recon), axis=(1,2))
threshold = float(np.percentile(train_errors, 98))
preds = (test_errors > threshold).astype(int)
actuals = df_all['is_anomaly'].values[SEQUENCE_LENGTH-1:][:len(preds)]
print(classification_report(actuals, preds, target_names=['Normal','Anomaly']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.56      0.71     20926
#      Anomaly       0.05      0.82      0.10       645
#
#     accuracy                           0.57     21571
#    macro avg       0.52      0.69      0.41     21571
# weighted avg       0.96      0.57      0.70     21571

# %%
# Training Loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss', color='#2196F3', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', color='#FF5722', linewidth=2)
plt.title(MODEL_NAME+' - Training vs Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch'); plt.ylabel('MSE'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Reconstruction Error
plt.figure(figsize=(10,5))
plt.hist(train_errors, bins=80, color='#2196F3', alpha=0.7, edgecolor='black')
plt.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.title(MODEL_NAME+' - Reconstruction Error Distribution', fontsize=14, fontweight='bold')
plt.xlabel('MSE'); plt.ylabel('Frequency'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Confusion Matrix
cm = confusion_matrix(actuals, preds)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal','Anomaly'], yticklabels=['Normal','Anomaly'])
plt.title(MODEL_NAME+' - Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.tight_layout(); plt.show()

# ROC Curve
fpr,tpr,_ = roc_curve(actuals, test_errors[:len(actuals)])
roc_auc = auc(fpr,tpr)
plt.figure(figsize=(7,5))
plt.plot(fpr,tpr, color='#2196F3', linewidth=2, label=f'AUC = {roc_auc:.4f}')
plt.plot([0,1],[0,1], color='gray', linestyle='--')
plt.title(MODEL_NAME+' - ROC Curve', fontsize=14, fontweight='bold')
plt.xlabel('FPR'); plt.ylabel('TPR'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()
print(f"AUC Score: {roc_auc:.4f}")
# Out:
# AUC Score: 0.7467

# %%
python
from tensorflow.keras import layers
# Reconstruct the 4 sensor features
model.add(layers.TimeDistributed(layers.Dense(4)))

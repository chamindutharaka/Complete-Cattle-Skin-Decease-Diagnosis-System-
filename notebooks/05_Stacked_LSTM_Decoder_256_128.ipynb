# %% [markdown]
# # V. Stacked LSTM Decoder (256 units → 128 units)
# Larger architecture variant for comparison.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
import warnings; warnings.filterwarnings('ignore')

df = pd.read_csv('../dl_service/data/cattle_training_data.csv', parse_dates=['timestamp'])
FEATURES = ['temperature', 'humidity', 'heartRate', 'distance', 'hour', 'day_of_week']
SEQUENCE_LENGTH = 30
N_FEATURES = len(FEATURES)

df_normal = df[df['is_anomaly']==0].dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(df_normal[FEATURES].values)

def create_sequences(data, sl):
    return np.array([data[i:i+sl] for i in range(len(data)-sl+1)], dtype=np.float32)

all_seq = create_sequences(scaled, SEQUENCE_LENGTH)
print(f"Sequences: {all_seq.shape}")
# Out:
# Sequences: (20926, 30, 6)

# %%
MODEL_NAME = 'Stacked LSTM (256→128)'
model = models.Sequential([
    layers.Input(shape=(SEQUENCE_LENGTH, N_FEATURES)),
    layers.LSTM(256, activation='tanh', return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(128, activation='tanh', return_sequences=False),
    layers.Dropout(0.2),
    layers.RepeatVector(SEQUENCE_LENGTH),
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(256, activation='tanh', return_sequences=True),
    layers.TimeDistributed(layers.Dense(N_FEATURES)),
])
model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 256)        │       269,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 30, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 30, 256)        │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 30, 6)          │         1,542 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 993,798 (3.79 MB)
#  Trainable params: 993,798 (3.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(all_seq, all_seq, epochs=100, batch_size=64, validation_split=0.15,
    callbacks=[callbacks.EarlyStopping(monitor='val_loss',patience=12,restore_best_weights=True),
               callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=6,min_lr=1e-6)], verbose=1)
train_recon = model.predict(all_seq, verbose=0)
train_errors = np.mean(np.square(all_seq - train_recon), axis=(1,2))
print(f"Mean Error: {np.mean(train_errors):.6f}")
# Out:
# Epoch 1/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 144s 487ms/step - loss: 0.0256 - val_loss: 0.0150 - learning_rate: 0.0010
# Epoch 2/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 126s 455ms/step - loss: 0.0147 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 3/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 133s 480ms/step - loss: 0.0135 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 4/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 133s 478ms/step - loss: 0.0129 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 5/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 130s 469ms/step - loss: 0.0126 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 6/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 128s 459ms/step - loss: 0.0126 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 7/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 114s 411ms/step - loss: 0.0125 - val_loss: 0.0119 - learning_rate: 0.0010
# Epoch 8/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 382ms/step - loss: 0.0124 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 9/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 98s 354ms/step - loss: 0.0121 - val_loss: 0.0119 - learning_rate: 0.0010
# Epoch 10/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 339ms/step - loss: 0.0120 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 11/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 93s 333ms/step - loss: 0.0119 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 12/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 99s 356ms/step - loss: 0.0119 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 13/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 99s 356ms/step - loss: 0.0118 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 14/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 339ms/step - loss: 0.0118 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 15/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 338ms/step - loss: 0.0117 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 16/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 99s 354ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 17/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 109s 394ms/step - loss: 0.0115 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 18/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 107s 386ms/step - loss: 0.0114 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 19/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 380ms/step - loss: 0.0113 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 20/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 110s 394ms/step - loss: 0.0112 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 21/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 110s 394ms/step - loss: 0.0111 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 22/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 102s 368ms/step - loss: 0.0110 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 23/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 97s 348ms/step - loss: 0.0110 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 24/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 322ms/step - loss: 0.0109 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 25/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 319ms/step - loss: 0.0107 - val_loss: 0.0103 - learning_rate: 0.0010
# Epoch 26/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 91s 326ms/step - loss: 0.0106 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 27/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 319ms/step - loss: 0.0105 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 28/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 322ms/step - loss: 0.0103 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 29/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 338ms/step - loss: 0.0102 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 30/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 94s 340ms/step - loss: 0.0101 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 31/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 380ms/step - loss: 0.0100 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 32/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 111s 400ms/step - loss: 0.0100 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 33/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 112s 403ms/step - loss: 0.0098 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 34/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 112s 404ms/step - loss: 0.0096 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 35/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 116s 418ms/step - loss: 0.0095 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 36/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 116s 417ms/step - loss: 0.0094 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 37/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 117s 419ms/step - loss: 0.0093 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 38/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 121s 436ms/step - loss: 0.0092 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 39/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 127s 455ms/step - loss: 0.0091 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 40/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 136s 488ms/step - loss: 0.0090 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 41/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 163s 587ms/step - loss: 0.0089 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 42/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 148s 531ms/step - loss: 0.0090 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 43/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 154s 555ms/step - loss: 0.0088 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 44/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 160s 577ms/step - loss: 0.0086 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 45/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 164s 588ms/step - loss: 0.0085 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 46/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 169s 606ms/step - loss: 0.0084 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 47/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 176s 633ms/step - loss: 0.0083 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 48/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 176s 634ms/step - loss: 0.0082 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 49/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 181s 650ms/step - loss: 0.0081 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 50/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 184s 663ms/step - loss: 0.0080 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 51/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 185s 666ms/step - loss: 0.0079 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 52/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 185s 666ms/step - loss: 0.0079 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 53/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 191s 687ms/step - loss: 0.0077 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 54/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 194s 698ms/step - loss: 0.0077 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 55/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 187s 672ms/step - loss: 0.0076 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 56/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 157s 564ms/step - loss: 0.0076 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 57/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 184s 663ms/step - loss: 0.0075 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 58/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 148s 534ms/step - loss: 0.0074 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 59/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 130s 466ms/step - loss: 0.0073 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 60/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 129s 464ms/step - loss: 0.0073 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 61/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 125s 448ms/step - loss: 0.0072 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 62/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 119s 428ms/step - loss: 0.0072 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 63/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 121s 436ms/step - loss: 0.0071 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 64/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 120s 431ms/step - loss: 0.0071 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 65/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 442ms/step - loss: 0.0070 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 66/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 442ms/step - loss: 0.0070 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 67/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 125s 448ms/step - loss: 0.0069 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 68/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 124s 447ms/step - loss: 0.0069 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 69/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 127s 457ms/step - loss: 0.0068 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 70/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 125s 451ms/step - loss: 0.0068 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 71/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 442ms/step - loss: 0.0068 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 72/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 120s 431ms/step - loss: 0.0067 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 73/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 121s 436ms/step - loss: 0.0068 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 74/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 444ms/step - loss: 0.0066 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 75/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 443ms/step - loss: 0.0066 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 76/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 124s 445ms/step - loss: 0.0065 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 77/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 122s 439ms/step - loss: 0.0065 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 78/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 122s 438ms/step - loss: 0.0065 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 79/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 123s 441ms/step - loss: 0.0062 - val_loss: 0.0059 - learning_rate: 5.0000e-04
# Epoch 80/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 125s 449ms/step - loss: 0.0062 - val_loss: 0.0058 - learning_rate: 5.0000e-04
# Epoch 81/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 114s 410ms/step - loss: 0.0062 - val_loss: 0.0059 - learning_rate: 5.0000e-04
# Epoch 82/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 110s 397ms/step - loss: 0.0061 - val_loss: 0.0058 - learning_rate: 5.0000e-04
# Epoch 83/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 114s 409ms/step - loss: 0.0061 - val_loss: 0.0058 - learning_rate: 5.0000e-04
# Epoch 84/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 117s 420ms/step - loss: 0.0061 - val_loss: 0.0058 - learning_rate: 5.0000e-04
# Epoch 85/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 382ms/step - loss: 0.0060 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 86/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 107s 384ms/step - loss: 0.0060 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 87/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 108s 389ms/step - loss: 0.0060 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 88/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 380ms/step - loss: 0.0060 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 89/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 383ms/step - loss: 0.0060 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 90/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 106s 381ms/step - loss: 0.0059 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 91/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 92s 332ms/step - loss: 0.0059 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 92/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 319ms/step - loss: 0.0059 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 93/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 86s 310ms/step - loss: 0.0059 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 94/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 319ms/step - loss: 0.0059 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 95/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 321ms/step - loss: 0.0059 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 96/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 91s 328ms/step - loss: 0.0057 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 97/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 86s 311ms/step - loss: 0.0057 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 98/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 307ms/step - loss: 0.0057 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 99/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 88s 316ms/step - loss: 0.0057 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 100/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 89s 321ms/step - loss: 0.0057 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Mean Error: 0.005068

# %%
# Evaluate on full dataset
df_all = df.dropna(subset=FEATURES).sort_values(['cattle_id','timestamp']).reset_index(drop=True)
test_scaled = scaler.transform(df_all[FEATURES].values)
test_seq = create_sequences(test_scaled, SEQUENCE_LENGTH)
test_recon = model.predict(test_seq, verbose=0)
test_errors = np.mean(np.square(test_seq - test_recon), axis=(1,2))
threshold = float(np.percentile(train_errors, 98))
preds = (test_errors > threshold).astype(int)
actuals = df_all['is_anomaly'].values[SEQUENCE_LENGTH-1:][:len(preds)]
print(classification_report(actuals, preds, target_names=['Normal','Anomaly']))

# %%
# Training Loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss', color='#2196F3', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', color='#FF5722', linewidth=2)
plt.title(MODEL_NAME+' - Training vs Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch'); plt.ylabel('MSE'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Reconstruction Error
plt.figure(figsize=(10,5))
plt.hist(train_errors, bins=80, color='#2196F3', alpha=0.7, edgecolor='black')
plt.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.title(MODEL_NAME+' - Reconstruction Error Distribution', fontsize=14, fontweight='bold')
plt.xlabel('MSE'); plt.ylabel('Frequency'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# Confusion Matrix
cm = confusion_matrix(actuals, preds)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal','Anomaly'], yticklabels=['Normal','Anomaly'])
plt.title(MODEL_NAME+' - Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.tight_layout(); plt.show()

# ROC Curve
fpr,tpr,_ = roc_curve(actuals, test_errors[:len(actuals)])
roc_auc = auc(fpr,tpr)
plt.figure(figsize=(7,5))
plt.plot(fpr,tpr, color='#2196F3', linewidth=2, label=f'AUC = {roc_auc:.4f}')
plt.plot([0,1],[0,1], color='gray', linestyle='--')
plt.title(MODEL_NAME+' - ROC Curve', fontsize=14, fontweight='bold')
plt.xlabel('FPR'); plt.ylabel('TPR'); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()
print(f"AUC Score: {roc_auc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#      10 plt.figure(figsize=(10,5))
#      11 plt.hist(train_errors, bins=80, color='#2196F3', alpha=0.7, edgecolor='black')
# ---> 12 plt.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold:.4f}')
#      13 plt.title(MODEL_NAME+' - Reconstruction Error Distribution', fontsize=14, fontweight='bold')
#      14 plt.xlabel('MSE'); plt.ylabel('Frequency'); plt.legend(); plt.grid(True, alpha=0.3)
#
# NameError: name 'threshold' is not defined
